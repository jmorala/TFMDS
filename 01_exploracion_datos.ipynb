# %% [markdown]
# <a href="https://colab.research.google.com/github/jmorala/TFMDS/blob/main/01_exploracion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Reemplaza 'tu_usuario' con tu nombre de usuario de GitHub
# Este comando descarga el repositorio entero a una carpeta llamada 'TFMDS' en Colab.
# !git clone https://github.com/jmorala/TFMDS.git
# Out:
# Cloning into 'TFMDS'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 29 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 4.07 MiB | 3.39 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import os

# Entra en la carpeta del proyecto
os.chdir('TFMDS')

# OPCIONAL: Para verificar que estás en la ruta correcta y ver las carpetas
print("Directorio de trabajo actual:", os.getcwd())
print("Contenido del directorio:")
# !ls -l
# Out:
# Directorio de trabajo actual: /content/TFMDS
# Contenido del directorio:
# total 20
# -rw-r--r-- 1 root root  912 Nov  4 15:10 01_exploracion_datos.ipynb
# drwxr-xr-x 2 root root 4096 Nov  4 15:10 cuadernos
# drwxr-xr-x 2 root root 4096 Nov  4 15:10 datos
# drwxr-xr-x 2 root root 4096 Nov  4 15:10 documentacion
# -rw-r--r-- 1 root root   63 Nov  4 15:10 README.md
